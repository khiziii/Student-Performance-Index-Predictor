# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
data = pd.read_csv('Student_performance.csv')

# %%
data
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 468.9+ KB

# %%
intdata = data.drop(['Extracurricular Activities'], axis=1)

# %%
intdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 5 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Sleep Hours                       10000 non-null  int64
#  3   Sample Question Papers Practiced  10000 non-null  int64
#  4   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4)
# memory usage: 390.8 KB

# %%
intdata.hist(figsize=(15,9))
# Out:
# array([[<Axes: title={'center': 'Hours Studied'}>,
#         <Axes: title={'center': 'Previous Scores'}>],
#        [<Axes: title={'center': 'Sleep Hours'}>,
#         <Axes: title={'center': 'Sample Question Papers Practiced'}>],
#        [<Axes: title={'center': 'Performance Index'}>, <Axes: >]],
#       dtype=object)

# %%
sns.heatmap(intdata.corr(), annot= True, cmap= 'YlGnBu')
# Out:
# <Axes: >

# %%
sns.boxplot(x='Extracurricular Activities', y='Performance Index', data=data)
# Out:
# <Axes: xlabel='Extracurricular Activities', ylabel='Performance Index'>

# %%
data
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
intdata.hist()
# Out:
# array([[<Axes: title={'center': 'Hours Studied'}>,
#         <Axes: title={'center': 'Previous Scores'}>],
#        [<Axes: title={'center': 'Sleep Hours'}>,
#         <Axes: title={'center': 'Sample Question Papers Practiced'}>],
#        [<Axes: title={'center': 'Performance Index'}>, <Axes: >]],
#       dtype=object)

# %%
sns.scatterplot(x="Previous Scores", y= 'Performance Index', data= intdata, hue='Hours Studied', palette='coolwarm')
plt.figure(figsize=(15,9))

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
x = intdata.drop(['Performance Index'], axis= 1)

# %%
y = intdata['Performance Index']

# %%
x
# Out:
#       Hours Studied  Previous Scores  Sleep Hours  \
# 0                 7               99            9
# 1                 4               82            4
# 2                 8               51            7
# 3                 5               52            5
# 4                 7               75            8
# ...             ...              ...          ...
# 9995              1               49            4
# 9996              7               64            8
# 9997              6               83            8
# 9998              9               97            7
# 9999              7               74            8
#
#       Sample Question Papers Practiced
# 0                                    1
# 1                                    2
# 2                                    2
# 3                                    2
# 4                                    5
# ...                                ...
# 9995                                 2
# 9996                                 5
# ...

# %%
y
# Out:
# 0       91.0
# 1       65.0
# 2       45.0
# 3       36.0
# 4       66.0
#         ...
# 9995    23.0
# 9996    58.0
# 9997    74.0
# 9998    95.0
# 9999    64.0
# Name: Performance Index, Length: 10000, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2)

# %%
train_data = x_train.join(y_train)

# %%
reg= LinearRegression()

# %%
reg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
reg.score(x_test, y_test)
# Out:
# 0.9883880474737399

# %%
import joblib

# %%
data
# Out:
#       Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0                 7               99                        Yes            9
# 1                 4               82                         No            4
# 2                 8               51                        Yes            7
# 3                 5               52                        Yes            5
# 4                 7               75                         No            8
# ...             ...              ...                        ...          ...
# 9995              1               49                        Yes            4
# 9996              7               64                        Yes            8
# 9997              6               83                        Yes            8
# 9998              9               97                        Yes            7
# 9999              7               74                         No            8
#
# ...

# %%
joblib.dump(reg, 'SPML.joblib')
# Out:
# ['SPML.joblib']
